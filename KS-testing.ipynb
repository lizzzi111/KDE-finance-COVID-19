# %%
import pandas as pd
import numpy as np
import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_post_COVID = pd.read_csv('data/densities_post_covid.csv')
df_pre_COVID  = pd.read_csv('data/densities_pre_covid.csv')

# %%
df_post_COVID.drop('x', axis=1).plot()

# %%
df_post_COVID.columns
# Out:
# Index(['x', 'dax_TVKDE', 'nq_TVKDE', 'dow_TVKDE', 'crix_TVKDE', 'snp500_TVKDE',
#        'btc_TVKDE', 'dax_U', 'nq_U', 'dow_U', 'crix_U', 'snp500_U', 'btc_U'],
#       dtype='object')

# %%
df_post_COVID[['dax_TVKDE', 'dax_U']].plot()

# %%
df_post_COVID[['btc_TVKDE', 'btc_U']]
# Out:
#       btc_TVKDE     btc_U
# 0      0.000743  0.000744
# 1      0.000785  0.000785
# 2      0.000827  0.000828
# 3      0.000870  0.000871
# 4      0.000914  0.000914
# 5      0.000958  0.000958
# 6      0.001002  0.001003
# 7      0.001046  0.001047
# 8      0.001090  0.001091
# 9      0.001134  0.001134
# 10     0.001177  0.001178
# 11     0.001219  0.001220
# 12     0.001261  0.001262
# 13     0.001301  0.001303
# 14     0.001341  0.001342
# 15     0.001379  0.001380
# 16     0.001415  0.001416
# 17     0.001449  0.001451
# 18     0.001482  0.001483
# 19     0.001512  0.001513
# 20     0.001540  0.001541
# 21     0.001566  0.001567
# 22     0.001589  0.001590
# 23     0.001609  0.001610
# 24     0.001626  0.001628
# 25     0.001641  0.001642
# 26     0.001652  0.001653
# 27     0.001660  0.001662
# 28     0.001665  0.001667
# 29     0.001667  0.001669
# ...         ...       ...
# 1970   0.001667  0.001668
# 1971   0.001667  0.001668
# 1972   0.001664  0.001665
# ...

# %%
df_post_COVID[['dax_TVKDE', 'dax_U']]
# Out:
#          dax_TVKDE         dax_U
# 0     2.220446e-16  2.220446e-16
# 1     2.154655e-16  2.088864e-16
# 2     2.286237e-16  2.220446e-16
# 3     2.220446e-16  2.220446e-16
# 4     2.088864e-16  2.352028e-16
# 5     2.286237e-16  2.154655e-16
# 6     1.891491e-16  2.417819e-16
# 7     2.220446e-16  2.286237e-16
# 8     2.154655e-16  2.483610e-16
# 9     2.352028e-16  2.154655e-16
# 10    2.286237e-16  2.154655e-16
# 11    2.154655e-16  2.417819e-16
# 12    2.088864e-16  2.286237e-16
# 13    2.088864e-16  2.220446e-16
# 14    1.891491e-16  2.220446e-16
# 15    2.154655e-16  1.891491e-16
# 16    2.286237e-16  2.220446e-16
# 17    2.023073e-16  2.154655e-16
# 18    2.286237e-16  2.154655e-16
# 19    2.023073e-16  2.154655e-16
# 20    2.088864e-16  2.417819e-16
# 21    2.483610e-16  2.483610e-16
# 22    1.957282e-16  2.483610e-16
# 23    2.220446e-16  2.483610e-16
# 24    1.694118e-16  2.088864e-16
# 25    2.483610e-16  2.352028e-16
# 26    2.352028e-16  2.088864e-16
# ...
